# %% [markdown]
# <a href="https://colab.research.google.com/github/trprince21/mass_shootings_R_data_visualizations/blob/main/Shooter_Mental_Illness_History.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
path="/content/drive/MyDrive/DataBlog/mass_shooting_events_stanford_msa_release_06142016.csv"
df=pd.read_csv(path)
df['History of Mental Illness - Detailed'].head(5)
# Out:
# 0    Shooter had visited  a psychiatrist and severa...
# 1     Diagnosed as schizophrenic. Possible psychopathy
# 2    During his time at the US Navy, the shooter si...
# 3    The student was acquitted of murder charges by...
# 4    In April 1975, the shooter entered a plea of n...
# Name: History of Mental Illness - Detailed, dtype: object

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS , ImageColorGenerator

# %%
stop_w = ['a', 'as', 'NaN', 'of', 'the', 'shooter', 'Name', 'had', 'Possible', 
          'by', 'In', 'at', 'n', 'and', 'was', 'si', 'dtype', 'during', 'severa',
          'Detailed', 'Mental', 'entered', 'object', 'History', 'Length']

# %%
wordcloud = WordCloud(stopwords = stop_w, 
                      width=1600, height=800,
                      colormap = 'winter',
                      background_color="white"
                      ).generate(str(df['History of Mental Illness - Detailed']))

# %%
plt.figure(figsize=(20,10),facecolor='k')
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
wordcloud.to_file("shooter_info_wordcloud.png")

# %%
##### create bar charts from word cloud to show criminal history #####

# %%
path2="/content/drive/MyDrive/DataBlog/mental_illness_list.txt"
f = open(path2)
mental_illness_list = f.read()
# Out:
# 3303

# %%
wordcloud = WordCloud(width=1600, height=800,
                      colormap = 'winter',
                      background_color="white"
                      ).generate(str(mental_illness_list))

# %%
plt.figure(figsize=(20,10),facecolor='k')
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
from itertools import repeat

unknown = list(repeat("unknown", 114))
none = list(repeat("none", 58))
personality_disorder = list(repeat("personality disorder", 3))
schizotypal_personality_disorder = list(repeat("schizotypal personality disorder", 1))
narcissistic_personality_disorder = list(repeat("narcissistic personality disorder", 1))
borderline_personality_disorder = list(repeat("borderline personality disorder", 3))
depression = list(repeat("depression", 31))
schizophrenia = list(repeat("schizophrenia", 24))
psychopathy = list(repeat("psychopathy", 1))
paranoia= list(repeat("paranoia", 27))
insanity = list(repeat("insanity", 13))
compulsivity = list(repeat("compulsivity", 4))
anxiety = list(repeat("anxiety", 6))
PTSD = list(repeat("PTSD", 8))
bipolar_disorder = list(repeat("bipolar disorder", 6))
OCD = list(repeat("OCD", 3))
dissociative_disorder = list(repeat("dissociative disorder", 2))
delusional_disorder = list(repeat("delusional disorder", 15))
panic_disorder = list(repeat("panic disorder", 1))
ADHD = list(repeat("ADHD", 1))
sensory_processing_disorder = list(repeat("sensory processing disorder", 1))
dysphoric_mania = list(repeat("dysphoric mania", 1))
grandiose = list(repeat("grandiose", 2))
character_behavior_disorder = list(repeat("character behavior disorder", 1))
pychosis = list(repeat("pychosis", 13))

mental_illnesses = unknown + none + personality_disorder + schizotypal_personality_disorder + narcissistic_personality_disorder + borderline_personality_disorder + depression + schizophrenia + psychopathy + paranoia + insanity + compulsivity + anxiety + PTSD + bipolar_disorder + OCD + dissociative_disorder + delusional_disorder + panic_disorder + ADHD + sensory_processing_disorder + dysphoric_mania + grandiose + character_behavior_disorder + pychosis

unique_string=(" ").join(mental_illnesses)
(unique_string)

# %%
wordcloud = WordCloud(width=1600, height=800,
                      colormap = 'winter',
                      background_color="white"
                      ).generate(" ".join(mental_illnesses))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from itertools import chain
from collections import Counter
from wordcloud import WordCloud

words = {
    "unknown": 114,
    "none": 58,
    "personality disorder": 3,
    "schizotypal personality disorder": 1,
    "narcissistic personality disorder": 1,
    "borderline personality disorder": 3,
    "depression": 31,
    "schizophrenia": 24,
    "psychopathy": 1,
    "paranoia": 27,
    "insanity": 13,
    "compulsivity": 4,
    "anxiety": 6,
    "PTSD": 8,
    "bipolar disorder": 6,
    "OCD": 3,
    "dissociative disorder": 2,
    "delusional disorder": 15,
    "panic disorder": 1,
    "ADHD": 1,
    "sensory processing disorder": 1,
    "dysphoric mania": 1,
    "grandiose": 2,
    "character behavior disorder": 1,
    "psychosis": 13
}

word_counts = Counter(words)

wordcloud = WordCloud(width=1600, height=800,
                      colormap='winter',
                      background_color="white"
                      ).generate_from_frequencies(word_counts)

wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1600x800 at 0x7FC34E0098E0>

# %%
wordcloud.to_file("shooter_mental_illness_wordcloud.png")
